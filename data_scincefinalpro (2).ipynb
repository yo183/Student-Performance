# %%
3-import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
 data_frame=pd.read_csv('Student_performance.csv')

# %%
data_frame
# Out:
#         roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 0        std-01    male        group D                some college    1.0
# 1        std-02    male        group B                 high school    1.0
# 2        std-03    male        group C             master's degree    1.0
# 3        std-04    male        group D                some college    1.0
# 4        std-05    male        group C                some college    0.0
# ...         ...     ...            ...                         ...    ...
# 9995   std-9996  female        group C                some college    1.0
# 9996   std-9997  female        group C           bachelor's degree    1.0
# 9997   std-9998  female        group B          associate's degree    1.0
# 9998   std-9999  female        group B            some high school    1.0
# 9999  std-10000  female        group B                 high school    1.0
#
#       test_preparation_course math_score  reading_score  writing_score  \
# ...

# %%
data_frame.head()
# Out:
#   roll_no gender race_ethnicity parental_level_of_education  lunch  \
# 0  std-01   male        group D                some college    1.0
# 1  std-02   male        group B                 high school    1.0
# 2  std-03   male        group C             master's degree    1.0
# 3  std-04   male        group D                some college    1.0
# 4  std-05   male        group C                some college    0.0
#
#    test_preparation_course math_score  reading_score  writing_score  \
# 0                      1.0         89           38.0           85.0
# 1                      0.0         65          100.0           67.0
# 2                      0.0         10           99.0           97.0
# 3                      1.0         22           51.0           41.0
# 4                      1.0         26           58.0           64.0
#
#    science_score  total_score grade
# 0           26.0        238.0     C
# 1           96.0        328.0     A
# 2           58.0        264.0     B
# ...

# %%
data_frame.shape
# Out:
# (10000, 12)

# %%
data_frame.describe()
# Out:
#              lunch  test_preparation_course  reading_score  writing_score  \
# count  9976.000000              9977.000000    9975.000000    9976.000000
# mean      0.644246                 0.388694      70.125915      71.415798
# std       0.478765                 0.487478      19.026245      18.245360
# min       0.000000                 0.000000      17.000000      10.000000
# 25%       0.000000                 0.000000      57.000000      59.000000
# 50%       1.000000                 0.000000      71.000000      72.500000
# 75%       1.000000                 1.000000      85.000000      85.000000
# max       1.000000                 1.000000     100.000000     100.000000
#
#        science_score  total_score
# count    9977.000000  9981.000000
# mean       66.063045   264.740908
# std        19.324331    42.304858
# min         9.000000    89.000000
# 25%        53.000000   237.000000
# 50%        67.000000   268.000000
# 75%        81.000000   294.000000
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   roll_no                      9999 non-null   object
#  1   gender                       9982 non-null   object
#  2   race_ethnicity               9977 non-null   object
#  3   parental_level_of_education  9978 non-null   object
#  4   lunch                        9976 non-null   float64
#  5   test_preparation_course      9977 non-null   float64
#  6   math_score                   9976 non-null   object
#  7   reading_score                9975 non-null   float64
#  8   writing_score                9976 non-null   float64
#  9   science_score                9977 non-null   float64
#  10  total_score                  9981 non-null   float64
#  11  grade                        9997 non-null   object
# dtypes: float64(6), object(6)
# ...

# %%
data_frame.isna().sum()
# Out:
# roll_no                         1
# gender                         18
# race_ethnicity                 23
# parental_level_of_education    22
# lunch                          24
# test_preparation_course        23
# math_score                     24
# reading_score                  25
# writing_score                  24
# science_score                  23
# total_score                    19
# grade                           3
# dtype: int64

# %%
data_frame.duplicated().sum()
# Out:
# 0

# %%
data_frame['lunch'] = data_frame['lunch'].fillna(0)
data_frame['test_preparation_course'] = data_frame['test_preparation_course'].fillna(0)
data_frame['reading_score'] = data_frame['reading_score'].fillna(0)
data_frame['writing_score'] = data_frame['writing_score'].fillna(0)
data_frame['science_score'] = data_frame['science_score'].fillna(0)
data_frame['total_score'] = data_frame['total_score'].fillna(0)


data_frame['lunch'] = data_frame['lunch'].astype(int)
data_frame['test_preparation_course'] = data_frame['test_preparation_course'].astype(int)
data_frame['reading_score'] = data_frame['reading_score'].astype(int)
data_frame['writing_score'] = data_frame['writing_score'].astype(int)
data_frame['science_score'] = data_frame['science_score'].astype(int)
data_frame['total_score'] = data_frame['total_score'].astype(int)


data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   roll_no                      9999 non-null   object
#  1   gender                       9982 non-null   object
#  2   race_ethnicity               9977 non-null   object
#  3   parental_level_of_education  9978 non-null   object
#  4   lunch                        10000 non-null  int32
#  5   test_preparation_course      10000 non-null  int32
#  6   math_score                   9976 non-null   object
#  7   reading_score                10000 non-null  int32
#  8   writing_score                10000 non-null  int32
#  9   science_score                10000 non-null  int32
#  10  total_score                  10000 non-null  int32
#  11  grade                        9997 non-null   object
# dtypes: int32(6), object(6)
# memory usage: 703.3+ KB

# %%
data_frame
# Out:
#         roll_no  gender race_ethnicity parental_level_of_education  lunch  \
# 0        std-01    male        group D                some college      1
# 1        std-02    male        group B                 high school      1
# 2        std-03    male        group C             master's degree      1
# 3        std-04    male        group D                some college      1
# 4        std-05    male        group C                some college      0
# ...         ...     ...            ...                         ...    ...
# 9995   std-9996  female        group C                some college      1
# 9996   std-9997  female        group C           bachelor's degree      1
# 9997   std-9998  female        group B          associate's degree      1
# 9998   std-9999  female        group B            some high school      1
# 9999  std-10000  female        group B                 high school      1
#
#       test_preparation_course math_score  reading_score  writing_score  \
# ...

# %%
categorical_columns = ['gender', 'race_ethnicity', 'parental_level_of_education', 'grade']
for col in categorical_columns:
    data_frame[col] = data_frame[col].fillna(data_frame[col].mode()[0])

numerical_columns = ['reading_score', 'writing_score', 'science_score', 'total_score']
for col in numerical_columns:
   
    data_frame[col] = data_frame[col].fillna(data_frame[col].mean())


data_frame['math_score'] = pd.to_numeric(data_frame['math_score'], errors='coerce')  
data_frame['math_score'] = data_frame['math_score'].fillna(data_frame['math_score'].mean())
categorical_numeric_columns = ['lunch', 'test_preparation_course']
for col in categorical_numeric_columns:
    data_frame[col] = data_frame[col].astype(str) 
    data_frame[col] = data_frame[col].fillna('Unknown')  
    data_frame[col] = data_frame[col].astype('category') 
    data_frame[col] = data_frame[col].fillna(data_frame[col].mode()[0])
data_frame['roll_no'] = data_frame['roll_no'].fillna('Unknown')
def clean_race_ethnicity(value):
    if pd.isna(value):`
        return 'Unknown' 
    value = str(value).strip().replace("\\n", "")  
    if len(value) == 1 and value.isalpha(): 
        return f"group {value}"
    return value
    import pandas as pd


data_frame['gender'] = data_frame['gender'].str.strip()  
data_frame['gender'] = data_frame['gender'].str.lower()  
data_frame['gender'] = data_frame['gender'].replace({
    'boy': 'male', 
    'girl': 'female', 
    '\\tmale': 'male', 
    '\\nfemale': 'female'  
})


cleaned_values = data_frame['race_ethnicity'].unique()
data_frame.drop_duplicates(inplace=True)
print("information after cleaning:")
print(data_frame.info())

print(data_frame.head())
# Out:
# information after cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   roll_no                      10000 non-null  object
#  1   gender                       10000 non-null  object
#  2   race_ethnicity               10000 non-null  object
#  3   parental_level_of_education  10000 non-null  object
#  4   lunch                        10000 non-null  category
#  5   test_preparation_course      10000 non-null  category
#  6   math_score                   10000 non-null  float64
#  7   reading_score                10000 non-null  int32
#  8   writing_score                10000 non-null  int32
#  9   science_score                10000 non-null  int32
#  10  total_score                  10000 non-null  int32
#  11  grade                        10000 non-null  object
# ...

# %%
data_frame
# Out:
#         roll_no  gender race_ethnicity parental_level_of_education lunch  \
# 0        std-01    male        group D                some college     1
# 1        std-02    male        group B                 high school     1
# 2        std-03    male        group C             master's degree     1
# 3        std-04    male        group D                some college     1
# 4        std-05    male        group C                some college     0
# ...         ...     ...            ...                         ...   ...
# 9995   std-9996  female        group C                some college     1
# 9996   std-9997  female        group C           bachelor's degree     1
# 9997   std-9998  female        group B          associate's degree     1
# 9998   std-9999  female        group B            some high school     1
# 9999  std-10000  female        group B                 high school     1
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
data_frame.isna().sum()
# Out:
# roll_no                        0
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# science_score                  0
# total_score                    0
# grade                          0
# dtype: int64

# %%
data_frame['grade'].value_counts().plot(
    kind='pie',
    title='Student Performance by Grade',
    figsize=(5, 5),
    autopct='%1.1f%%',
    legend=True
)
# Out:
# <Axes: title={'center': 'Student Performance by Grade'}, ylabel='count'>

# %%
gender_means = data_frame.groupby('gender')[['math_score', 'reading_score', 'writing_score', 'science_score']].mean()

plt.figure(figsize=(10, 6))
gender_means.T.plot(kind='bar', figsize=(10, 6), colormap='Set2')
plt.title('Average Scores by Gender', fontsize=16)
plt.xlabel('Subjects', fontsize=14)
plt.ylabel('Average Score', fontsize=14)
plt.legend(title='Gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

sns.countplot(x='grade', hue='lunch', data=data_frame, palette="Set2")

plt.title('Distribution of Grades by Lunch Type', fontsize=16)
plt.xlabel('Grade', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()


plt.show()
